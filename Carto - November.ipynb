# %% [markdown]
# # Data Science Take Home Test
#
# ## Initialization

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import time
start_time = time.time()

# %% [markdown]
# Load data

# %%
df_mes = pd.read_csv('I:\Javier Resano\Curriculum\Caso Carto\yellow_tripdata_2017-11.csv', sep=',')

# %% [markdown]
# ## Data Exploration and Cleaning

# %%
df_mes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9284803 entries, 0 to 9284802
# Data columns (total 17 columns):
# VendorID                 int64
# tpep_pickup_datetime     object
# tpep_dropoff_datetime    object
# passenger_count          int64
# trip_distance            float64
# RatecodeID               int64
# store_and_fwd_flag       object
# PULocationID             int64
# DOLocationID             int64
# payment_type             int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# dtypes: float64(8), int64(6), object(3)
# memory usage: 1.2+ GB

# %% [markdown]
# **To note:**
# -  "tpep_pickup_datetime" and "tpep_dropoff_datetime" should be datetime
# - PULocationID, DOLocationID, payment_type, RateCodeID are really numeric codes. I'll transform them to strings

# %%
df_mes['tpep_pickup_datetime'] = pd.to_datetime(df_mes['tpep_pickup_datetime'])
df_mes['tpep_dropoff_datetime'] = pd.to_datetime(df_mes['tpep_dropoff_datetime'])
df_mes['PULocationID'] = df_mes['PULocationID'].astype(str)
df_mes['DOLocationID'] = df_mes['DOLocationID'].astype(str)
df_mes['payment_type'] = df_mes['payment_type'].astype(str)
df_mes['RatecodeID'] = df_mes['RatecodeID'].astype(str)
df_mes['VendorID'] = df_mes['VendorID'].astype(str)

# %%
with pd.option_context('float_format', '{:.2f}'.format): print(df_mes.describe()) #10.294.628 cases
# Out:
#        passenger_count  trip_distance  fare_amount      extra    mta_tax  \
# count       9284803.00     9284803.00   9284803.00 9284803.00 9284803.00
# mean              1.61           2.90        13.14       0.32       0.50
# std               1.26           3.73       129.61       0.45       0.06
# min               0.00           0.00      -499.00     -48.64      -0.50
# 25%               1.00           0.97         6.50       0.00       0.50
# 50%               1.00           1.60         9.50       0.00       0.50
# 75%               2.00           3.00        15.00       0.50       0.50
# max             192.00         702.50    393221.50      69.80      96.00
#
#        tip_amount  tolls_amount  improvement_surcharge  total_amount
# count  9284803.00    9284803.00             9284803.00    9284803.00
# mean         1.89          0.34                   0.30         16.49
# std          2.62          1.98                   0.01        129.89
# min       -112.00        -14.75                  -0.30       -499.30
# 25%          0.00          0.00                   0.30          8.75
# 50%          1.40          0.00                   0.30         12.00
# 75%          2.46          0.00                   0.30         17.90
# max        450.00       1018.95                   1.00     393222.32

# %% [markdown]
# ** Findings. Data issues: **
# - trip_distance sometimes is 0 (no travel?)
# - fare_amount sometimes contains negative numbers
# - extra sometimes contains negative numbers. Max value is strange too. Does not seem to match Data Dictionary explanation (only 0.5 or 1 charges)
# - mta_tax sometimes contains negative numbers. Max value is strange too. Does not seem to match Data Dictionary explanation (only 0.5 charges)
# - total_amount sometimes contains negative numbers
# - tip_amount sometimes contains negative numbers
# - tolls_amount sometimes contains negative numbers
# - improvement_surcharge sometimes contains negative numbers. Max value is strange too. Does not seem to match Data Dictionary explanation (only 0.3 charges)

# %% [markdown]
# Since we have a lot of data, I will remove wrong data. <br>
# Initial number of rows:

# %%
df_mes.shape[0]
# Out:
# 9284803

# %%
df_mes = df_mes[df_mes['trip_distance']>0]
df_mes.shape[0]
# Out:
# 9224250

# %%
df_mes = df_mes[df_mes['fare_amount']>0]
df_mes.shape[0]
# Out:
# 9219351

# %%
df_mes = df_mes[df_mes['extra']>=0]
df_mes.shape[0]
# Out:
# 9219344

# %%
df_mes = df_mes[df_mes['mta_tax']>=0]
df_mes.shape[0]
# Out:
# 9219344

# %%
df_mes = df_mes[df_mes['total_amount']>=0]
df_mes.shape[0]
# Out:
# 9219344

# %%
df_mes = df_mes[df_mes['tip_amount']>=0]
df_mes.shape[0]
# Out:
# 9219344

# %%
df_mes = df_mes[df_mes['tolls_amount']>=0]
df_mes.shape[0]
# Out:
# 9219344

# %%
df_mes = df_mes[df_mes['improvement_surcharge']>=0]
df_mes.shape[0]
# Out:
# 9219344

# %% [markdown]
# Now, I'll check and delete strange cases:

# %%
df_mes[(df_mes['improvement_surcharge']!=0.3)].shape[0]
# Out:
# 501

# %%
df_mes = df_mes[df_mes['improvement_surcharge']==0.3]
df_mes.shape[0]
# Out:
# 9218843

# %%
df_mes[(df_mes['mta_tax']!=0.5)&(df_mes['mta_tax']!=0)].shape[0]
# Out:
# 0

# %%
df_mes[(df_mes['extra']!=0)&(df_mes['extra']!=0.5)&(df_mes['extra']!=1)&(df_mes['extra']!=1.5)].shape[0]
# Out:
# 35442

# %%
df_mes[(df_mes['extra']!=0)&(df_mes['extra']!=0.5)&(df_mes['extra']!=1)&(df_mes['extra']!=1.5)].extra.unique()
# Out:
# array([4.50e+00, 6.98e+01, 6.42e+01, 2.00e-02, 1.01e+00, 6.00e-01,
#        3.00e-01, 6.52e+00, 4.54e+00, 4.04e+01, 2.00e+00, 3.00e+00,
#        3.50e+00, 7.50e-01, 8.00e-01])

# %%
df_mes = df_mes[(df_mes['extra']==0)|(df_mes['extra']==0.5)|(df_mes['extra']==1)|(df_mes['extra']==1.5)]
df_mes.shape[0]
# Out:
# 9183401

# %% [markdown]
# All in all we have gone from 10294628 to 10180582 rows. We are keeping 98.9% of the initial dataset

# %% [markdown]
# ### Feature Engineering
# In order to improve dataset quality, I am going to create some new features based on the existing ones

# %% [markdown]
# 1. Travel time

# %%
df_mes['travel_time'] = df_mes['tpep_dropoff_datetime'] - df_mes['tpep_pickup_datetime']
df_mes['travel_time'] = df_mes['travel_time'].dt.total_seconds()

# %% [markdown]
# 2. Average speed

# %%
df_mes['average_speed'] = df_mes['trip_distance'] / df_mes['travel_time'] *3600

# %% [markdown]
# 3. Hour of the day

# %%
df_mes['tpep_pickup_hour'] = pd.DatetimeIndex(df_mes['tpep_pickup_datetime']).hour
df_mes['tpep_dropoff_hour'] = pd.DatetimeIndex(df_mes['tpep_dropoff_datetime']).hour

# %% [markdown]
# 4. Day of the week

# %%
df_mes['tpep_pickup_weekday'] = pd.DatetimeIndex(df_mes['tpep_pickup_datetime']).weekday
df_mes['tpep_dropoff_weekday'] = pd.DatetimeIndex(df_mes['tpep_dropoff_datetime']).weekday

# %% [markdown]
# And we check their values:

# %%
with pd.option_context('float_format', '{:.2f}'.format): print(df_mes.loc[:,['travel_time','average_speed']].describe()) #10.294.628 cases
# Out:
#        travel_time  average_speed
# count   9183401.00     9183401.00
# mean       1055.00            inf
# std       15473.05            nan
# min       -3551.00        -257.69
# 25%         413.00           6.89
# 50%         694.00           9.47
# 75%        1140.00          13.08
# max    45466304.00            inf

# %% [markdown]
# Some new issues with data arise:
# - There are some negative travel_time values
# - "average_speed == inf" happens when travel_time is 0. Which mean there was no trip
# - Very high average speeds (> 100 mph) also are a mark of wrong data

# %%
df_mes[(df_mes['average_speed'] == np.inf) | (df_mes['average_speed'] > 100)]
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 168            1  2017-11-01 00:30:50   2017-11-01 00:31:44                1
# 794            2  2017-11-01 00:12:08   2017-11-01 00:12:12                1
# 857            2  2017-11-01 00:09:46   2017-11-01 00:09:49                1
# 1202           1  2017-11-01 00:05:23   2017-11-01 00:05:41                1
# 1454           1  2017-11-01 00:15:29   2017-11-01 00:16:11                1
# 3401           1  2017-11-01 00:01:22   2017-11-01 00:01:24                1
# 4120           1  2017-11-01 00:40:30   2017-11-01 00:40:52                1
# 6072           1  2017-11-01 00:29:17   2017-11-01 00:29:42                2
# 6518           1  2017-11-01 00:13:24   2017-11-01 00:13:53                1
# 7663           1  2017-11-01 00:30:51   2017-11-01 00:31:09                1
# 7905           1  2017-11-01 00:02:17   2017-11-01 00:02:26                1
# 8443           1  2017-11-01 00:15:52   2017-11-01 00:16:15                1
# 8977           1  2017-11-01 00:18:09   2017-11-01 00:18:53                2
# 9207           1  2017-11-01 00:36:50   2017-11-01 00:38:08                1
# 9615           1  2017-11-01 01:01:30   2017-11-01 01:02:43                1
# 10341          1  2017-11-01 01:16:47   2017-11-01 01:18:06                1
# 11895          1  2017-11-01 01:46:45   2017-11-01 01:46:52                1
# 12506          1  2017-11-01 01:02:59   2017-11-01 01:03:02                1
# 13261          1  2017-11-01 01:13:41   2017-11-01 01:14:29                1
# 13363          1  2017-11-01 01:56:15   2017-11-01 01:56:37                1
# 14168          1  2017-11-01 01:09:55   2017-11-01 01:10:19                1
# 14188          1  2017-11-01 01:16:15   2017-11-01 01:16:21                1
# 14880          1  2017-11-01 01:14:16   2017-11-01 01:14:51                1
# 16279          2  2017-11-01 01:12:15   2017-11-01 01:12:30                1
# 17203          2  2017-11-01 02:13:20   2017-11-01 02:13:23                4
# 18455          1  2017-11-01 02:09:51   2017-11-01 02:10:15                1
# 19632          1  2017-11-01 02:36:17   2017-11-01 02:37:39                1
# 19818          1  2017-11-01 02:54:32   2017-11-01 02:54:47                1
# 21418          1  2017-11-01 02:29:09   2017-11-01 02:29:39                5
# 21761          1  2017-11-01 03:27:22   2017-11-01 03:27:24                1
# ...          ...                  ...                   ...              ...
# 9262276        1  2017-11-30 22:11:40   2017-11-30 22:12:23                1
# 9263539        2  2017-11-30 23:22:11   2017-11-30 23:22:11                1
# 9263564        1  2017-11-30 22:12:12   2017-11-30 22:12:39                1
# 9264157        1  2017-11-30 22:20:55   2017-11-30 22:20:59                1
# 9264158        1  2017-11-30 22:23:09   2017-11-30 22:23:17                1
# 9264319        1  2017-11-30 22:37:14   2017-11-30 22:37:35                1
# 9266787        1  2017-11-30 23:30:11   2017-11-30 23:30:24                1
# 9266817        1  2017-11-30 23:32:25   2017-11-30 23:33:10                1
# 9267359        2  2017-12-01 00:12:42   2017-12-01 00:12:42                1
# 9267926        2  2017-11-30 00:06:01   2017-11-30 00:06:01                1
# 9268226        1  2017-11-30 23:12:25   2017-11-30 23:12:47                1
# 9269177        1  2017-11-30 23:34:17   2017-11-30 23:34:26                1
# 9271384        2  2017-11-30 00:11:41   2017-11-30 00:11:56                1
# 9271559        1  2017-11-30 23:20:34   2017-11-30 23:21:07                2
# 9271565        1  2017-11-30 23:49:50   2017-11-30 23:50:04                1
# 9273628        2  2017-11-30 23:49:43   2017-11-30 23:50:03                1
# 9274929        2  2017-12-01 00:19:44   2017-12-01 00:19:44                1
# 9275192        2  2017-12-01 00:21:11   2017-12-01 00:21:11                1
# 9275551        1  2017-11-30 23:20:29   2017-11-30 23:20:49                1
# 9276280        1  2017-11-30 23:41:46   2017-11-30 23:41:51                1
# 9276281        1  2017-11-30 23:43:40   2017-11-30 23:43:47                1
# 9277088        1  2017-11-30 23:54:20   2017-11-30 23:55:10                0
# 9277570        1  2017-11-30 23:15:33   2017-11-30 23:15:56                1
# 9278133        1  2017-11-30 23:10:36   2017-11-30 23:10:40                2
# 9278135        1  2017-11-30 23:54:20   2017-11-30 23:54:41                2
# 9278539        1  2017-11-30 23:12:22   2017-11-30 23:12:47                6
# 9278557        1  2017-11-30 23:06:38   2017-11-30 23:06:40                1
# 9279842        1  2017-11-30 23:36:17   2017-11-30 23:36:47                1
# 9279843        1  2017-11-30 23:37:29   2017-11-30 23:37:57                1
# 9283107        2  2017-12-01 00:27:34   2017-12-01 00:27:34                3
#
#          trip_distance RatecodeID store_and_fwd_flag PULocationID  \
# 168               5.00          5                  N          265
# 794               0.22          5                  N          264
# 857               1.17          1                  N          264
# 1202              3.30          1                  N           90
# 1454              4.60          5                  N          265
# 3401              1.30          5                  N          100
# 4120              0.90          5                  N           49
# 6072             16.30          5                  N          265
# 6518             16.80          5                  N          265
# 7663             16.10          2                  N          238
# 7905              0.90          1                  N          114
# 8443              4.10          1                  N          137
# 8977              6.40          5                  N           48
# 9207             48.40          5                  N          265
# 9615              2.90          1                  N          145
# 10341             7.90          1                  N          114
# 11895             0.60          1                  N          170
# 12506             0.80          1                  N          162
# 13261             3.00          5                  N          249
# 13363             5.50          5                  N          265
# 14168            16.10          5                  N           29
# 14188             2.50          1                  N           88
# 14880             1.40          5                  N           75
# 16279             0.82          1                  N          164
# 17203             0.14          5                  N           79
# 18455             2.60          1                  N          148
# 19632             7.10          1                  N          231
# 19818             1.60          5                  N           90
# 21418             1.70          1                  N           79
# 21761             1.30          1                  N           68
# ...                ...        ...                ...          ...
# 9262276           2.20          1                  N           79
# 9263539           2.33          1                  N          100
# 9263564           1.10          1                  N          229
# 9264157           0.60          1                  N          125
# 9264158           0.60          1                  N          158
# 9264319           1.90          5                  N          249
# 9266787           1.30          1                  N          265
# 9266817           1.30          1                  N          230
# 9267359           4.31          1                  N           25
# 9267926           7.54          1                  N          161
# 9268226           2.40          1                  N          144
# 9269177           0.80          1                  N          162
# 9271384          12.21          1                  N          161
# 9271559           3.00          5                  N          265
# 9271565          19.20          2                  N          249
# 9273628           2.35          1                  N          229
# 9274929           9.38          1                  N          237
# 9275192           7.52          1                  N           79
# 9275551           5.10          5                  N          265
# 9276280          21.20          2                  N          265
# 9276281          21.20          2                  N          265
# 9277088           2.60          1                  N           75
# 9277570           1.40          5                  N          265
# 9278133           0.90          1                  N          170
# 9278135          21.80          5                  Y          265
# 9278539           1.40          1                  N          264
# 9278557           1.10          1                  N           48
# 9279842          23.90          1                  Y          265
# 9279843          23.90          5                  Y          265
# 9283107           6.82          1                  N           68
#
#         DOLocationID payment_type          ...           tip_amount  \
# 168              265            1          ...                30.00
# 794              260            1          ...                 8.82
# 857              246            1          ...                 1.46
# 1202              90            2          ...                 0.00
# 1454             265            1          ...                 9.15
# 3401             100            1          ...                 1.75
# 4120              49            1          ...                 2.00
# 6072             265            1          ...                16.05
# 6518             265            1          ...                10.00
# 7663             238            1          ...                11.70
# 7905             114            3          ...                 0.00
# 8443             137            3          ...                 0.00
# 8977              48            1          ...                13.05
# 9207             265            1          ...                 0.00
# 9615             145            2          ...                 0.00
# 10341            114            2          ...                 0.00
# 11895            170            1          ...                21.20
# 12506            162            2          ...                 0.00
# 13261            249            1          ...                 0.00
# 13363            265            1          ...                 5.00
# 14168             29            1          ...                 0.00
# 14188             88            3          ...                 0.00
# 14880             75            1          ...                 0.00
# 16279            164            1          ...                 1.36
# 17203            107            1          ...                 4.06
# 18455            148            2          ...                 0.00
# 19632            211            2          ...                 0.00
# 19818             90            1          ...                 0.00
# 21418             79            3          ...                 0.00
# 21761             68            1          ...                 0.75
# ...              ...          ...          ...                  ...
# 9262276           79            3          ...                 0.00
# 9263539          161            2          ...                 0.00
# 9263564          229            2          ...                 0.00
# 9264157          125            3          ...                 0.00
# 9264158          158            3          ...                 0.00
# 9264319          249            1          ...                 1.80
# 9266787          265            1          ...               126.00
# 9266817          230            3          ...                 0.00
# 9267359           61            2          ...                 0.00
# 9267926           45            2          ...                 0.00
# 9268226          144            3          ...                 0.00
# 9269177          162            3          ...                 0.00
# 9271384           50            2          ...                 0.00
# 9271559          265            1          ...                 0.00
# 9271565          249            1          ...                 6.00
# 9273628          229            1          ...                 1.20
# 9274929           95            1          ...                 6.36
# 9275192           61            1          ...                 5.56
# 9275551          265            1          ...                13.85
# 9276280          265            1          ...                 0.00
# 9276281          265            1          ...                 0.00
# 9277088           75            2          ...                 0.00
# 9277570          265            1          ...                12.05
# 9278133          170            2          ...                 0.00
# 9278135          265            2          ...                 0.00
# 9278539          264            3          ...                 0.00
# 9278557           48            2          ...                 0.00
# 9279842          265            4          ...                 0.00
# 9279843          265            2          ...                 0.00
# 9283107           54            1          ...                 6.21
#
#          tolls_amount  improvement_surcharge  total_amount  travel_time  \
# 168              0.00                    0.3         90.30         54.0
# 794              0.00                    0.3         44.12          4.0
# 857              0.00                    0.3          8.76          3.0
# 1202             0.00                    0.3          3.80         18.0
# 1454            10.50                    0.3         54.95         42.0
# 3401             0.00                    0.3         10.55          2.0
# 4120             0.00                    0.3         29.00         22.0
# 6072             0.00                    0.3         96.35         25.0
# 6518             0.00                    0.3        138.30         29.0
# 7663             5.76                    0.3         70.26         18.0
# 7905             0.00                    0.3          3.80          9.0
# 8443             0.00                    0.3          3.80         23.0
# 8977             0.00                    0.3         78.35         44.0
# 9207            23.00                    0.3        187.30         78.0
# 9615             0.00                    0.3          4.30         73.0
# 10341            0.00                    0.3          4.30         79.0
# 11895            0.00                    0.3         25.00          7.0
# 12506            0.00                    0.3          3.80          3.0
# 13261            0.00                    0.3         30.30         48.0
# 13363            0.00                    0.3         55.30         22.0
# 14168            0.00                    0.3         10.30         24.0
# 14188            0.00                    0.3          3.80          6.0
# 14880            0.00                    0.3         60.30         35.0
# 16279            0.00                    0.3          8.16         15.0
# 17203            0.00                    0.3         24.36          3.0
# 18455            0.00                    0.3          3.80         24.0
# 19632            0.00                    0.3          4.30         82.0
# 19818            0.00                    0.3         15.30         15.0
# 21418            0.00                    0.3          3.80         30.0
# 21761            0.00                    0.3          4.55          2.0
# ...               ...                    ...           ...          ...
# 9262276          0.00                    0.3          2.80         43.0
# 9263539          0.00                    0.3         34.30          0.0
# 9263564          0.00                    0.3          3.80         27.0
# 9264157          0.00                    0.3          3.80          4.0
# 9264158          0.00                    0.3          3.80          8.0
# 9264319          0.00                    0.3         12.10         21.0
# 9266787          0.00                    0.3        129.80         13.0
# 9266817          0.00                    0.3          3.80         45.0
# 9267359          0.00                    0.3         16.80          0.0
# 9267926          0.00                    0.3         26.30          0.0
# 9268226          0.00                    0.3          3.80         22.0
# 9269177          0.00                    0.3          3.80          9.0
# 9271384          5.76                    0.3         47.06         15.0
# 9271559          0.00                    0.3         60.30         33.0
# 9271565          5.76                    0.3         64.56         14.0
# 9273628          0.00                    0.3         11.00         20.0
# 9274929          0.00                    0.3         38.16          0.0
# 9275192          0.00                    0.3         33.36          0.0
# 9275551          0.00                    0.3         83.15         20.0
# 9276280          0.00                    0.3         52.80          5.0
# 9276281          0.00                    0.3         52.80          7.0
# 9277088          0.00                    0.3          3.80         50.0
# 9277570          0.00                    0.3         72.35         23.0
# 9278133          0.00                    0.3          3.80          4.0
# 9278135          0.00                    0.3        100.00         21.0
# 9278539          0.00                    0.3          3.80         25.0
# 9278557          0.00                    0.3         10.30          2.0
# 9279842          0.00                    0.3          3.80         30.0
# 9279843          0.00                    0.3         91.30         28.0
# 9283107          5.76                    0.3         37.27          0.0
#
#          average_speed  tpep_pickup_hour  tpep_dropoff_hour  \
# 168       3.333333e+02                 0                  0
# 794       1.980000e+02                 0                  0
# 857       1.404000e+03                 0                  0
# 1202      6.600000e+02                 0                  0
# 1454      3.942857e+02                 0                  0
# 3401      2.340000e+03                 0                  0
# 4120      1.472727e+02                 0                  0
# 6072      2.347200e+03                 0                  0
# 6518      2.085517e+03                 0                  0
# 7663      3.220000e+03                 0                  0
# 7905      3.600000e+02                 0                  0
# 8443      6.417391e+02                 0                  0
# 8977      5.236364e+02                 0                  0
# 9207      2.233846e+03                 0                  0
# 9615      1.430137e+02                 1                  1
# 10341     3.600000e+02                 1                  1
# 11895     3.085714e+02                 1                  1
# 12506     9.600000e+02                 1                  1
# 13261     2.250000e+02                 1                  1
# 13363     9.000000e+02                 1                  1
# 14168     2.415000e+03                 1                  1
# 14188     1.500000e+03                 1                  1
# 14880     1.440000e+02                 1                  1
# 16279     1.968000e+02                 1                  1
# 17203     1.680000e+02                 2                  2
# 18455     3.900000e+02                 2                  2
# 19632     3.117073e+02                 2                  2
# 19818     3.840000e+02                 2                  2
# 21418     2.040000e+02                 2                  2
# 21761     2.340000e+03                 3                  3
# ...                ...               ...                ...
# 9262276   1.841860e+02                22                 22
# 9263539            inf                23                 23
# 9263564   1.466667e+02                22                 22
# 9264157   5.400000e+02                22                 22
# 9264158   2.700000e+02                22                 22
# 9264319   3.257143e+02                22                 22
# 9266787   3.600000e+02                23                 23
# 9266817   1.040000e+02                23                 23
# 9267359            inf                 0                  0
# 9267926            inf                 0                  0
# 9268226   3.927273e+02                23                 23
# 9269177   3.200000e+02                23                 23
# 9271384   2.930400e+03                 0                  0
# 9271559   3.272727e+02                23                 23
# 9271565   4.937143e+03                23                 23
# 9273628   4.230000e+02                23                 23
# 9274929            inf                 0                  0
# 9275192            inf                 0                  0
# 9275551   9.180000e+02                23                 23
# 9276280   1.526400e+04                23                 23
# 9276281   1.090286e+04                23                 23
# 9277088   1.872000e+02                23                 23
# 9277570   2.191304e+02                23                 23
# 9278133   8.100000e+02                23                 23
# 9278135   3.737143e+03                23                 23
# 9278539   2.016000e+02                23                 23
# 9278557   1.980000e+03                23                 23
# 9279842   2.868000e+03                23                 23
# 9279843   3.072857e+03                23                 23
# 9283107            inf                 0                  0
#
#          tpep_pickup_weekday  tpep_dropoff_weekday
# 168                        2                     2
# 794                        2                     2
# 857                        2                     2
# 1202                       2                     2
# 1454                       2                     2
# 3401                       2                     2
# 4120                       2                     2
# 6072                       2                     2
# 6518                       2                     2
# 7663                       2                     2
# 7905                       2                     2
# 8443                       2                     2
# 8977                       2                     2
# 9207                       2                     2
# 9615                       2                     2
# 10341                      2                     2
# 11895                      2                     2
# 12506                      2                     2
# 13261                      2                     2
# 13363                      2                     2
# 14168                      2                     2
# 14188                      2                     2
# 14880                      2                     2
# 16279                      2                     2
# 17203                      2                     2
# 18455                      2                     2
# 19632                      2                     2
# 19818                      2                     2
# 21418                      2                     2
# 21761                      2                     2
# ...                      ...                   ...
# 9262276                    3                     3
# 9263539                    3                     3
# 9263564                    3                     3
# 9264157                    3                     3
# 9264158                    3                     3
# 9264319                    3                     3
# 9266787                    3                     3
# 9266817                    3                     3
# 9267359                    4                     4
# 9267926                    3                     3
# 9268226                    3                     3
# 9269177                    3                     3
# 9271384                    3                     3
# 9271559                    3                     3
# 9271565                    3                     3
# 9273628                    3                     3
# 9274929                    4                     4
# 9275192                    4                     4
# 9275551                    3                     3
# 9276280                    3                     3
# 9276281                    3                     3
# 9277088                    3                     3
# 9277570                    3                     3
# 9278133                    3                     3
# 9278135                    3                     3
# 9278539                    3                     3
# 9278557                    3                     3
# 9279842                    3                     3
# 9279843                    3                     3
# 9283107                    4                     4
#
# [7844 rows x 23 columns]

# %%
df_mes = df_mes[(df_mes['average_speed'] != np.inf) & (df_mes['average_speed'] < 100)]
df_mes.shape[0]
# Out:
# 9175545

# %%
#I convert Timedelta value to float (number of seconds of the trip)
df_mes['travel_time'] = df_mes['travel_time'].astype('timedelta64[s]').dt.total_seconds()

# %%
df_mes[df_mes['travel_time'] < 0]
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1383804        1  2017-11-05 01:54:17   2017-11-05 01:22:16                1
# 1383813        1  2017-11-05 01:48:35   2017-11-05 01:02:50                1
# 1383844        1  2017-11-05 01:59:21   2017-11-05 01:02:24                2
# 1383858        1  2017-11-05 01:55:30   2017-11-05 01:03:32                1
# 1383865        1  2017-11-05 01:51:17   2017-11-05 01:02:42                2
# 1383899        1  2017-11-05 01:37:43   2017-11-05 01:05:01                1
# 1383904        1  2017-11-05 01:58:58   2017-11-05 01:02:35                1
# 1383925        1  2017-11-05 01:52:49   2017-11-05 01:05:34                1
# 1383932        1  2017-11-05 01:57:20   2017-11-05 01:30:19                1
# 1383936        1  2017-11-05 01:58:31   2017-11-05 01:10:34                1
# 1383954        1  2017-11-05 01:49:24   2017-11-05 01:07:16                1
# 1383958        1  2017-11-05 01:57:33   2017-11-05 01:14:37                3
# 1383973        1  2017-11-05 01:55:12   2017-11-05 01:02:35                2
# 1383975        1  2017-11-05 01:38:53   2017-11-05 01:06:00                2
# 1383989        1  2017-11-05 01:59:35   2017-11-05 01:11:26                1
# 1383995        1  2017-11-05 01:47:57   2017-11-05 01:08:34                4
# 1384007        1  2017-11-05 01:38:17   2017-11-05 01:07:53                1
# 1384011        1  2017-11-05 01:54:53   2017-11-05 01:03:40                2
# 1384020        1  2017-11-05 01:53:25   2017-11-05 01:27:17                2
# 1384023        1  2017-11-05 01:59:55   2017-11-05 01:28:38                1
# 1384032        1  2017-11-05 01:27:50   2017-11-05 01:09:22                2
# 1384043        1  2017-11-05 01:58:22   2017-11-05 01:07:05                2
# 1384054        1  2017-11-05 01:46:07   2017-11-05 01:08:27                2
# 1384057        1  2017-11-05 01:51:28   2017-11-05 01:11:22                2
# 1384060        1  2017-11-05 01:43:57   2017-11-05 01:08:41                1
# 1384070        1  2017-11-05 01:55:08   2017-11-05 01:05:18                2
# 1384092        1  2017-11-05 01:49:38   2017-11-05 01:11:27                2
# 1384098        1  2017-11-05 01:45:48   2017-11-05 01:06:56                1
# 1384103        1  2017-11-05 01:45:34   2017-11-05 01:22:32                2
# 1384113        1  2017-11-05 01:48:14   2017-11-05 01:01:16                1
# ...          ...                  ...                   ...              ...
# 1412354        1  2017-11-05 01:48:10   2017-11-05 01:09:36                1
# 1412357        1  2017-11-05 01:55:56   2017-11-05 01:15:48                1
# 1412367        1  2017-11-05 01:49:41   2017-11-05 01:13:56                1
# 1412370        1  2017-11-05 01:34:01   2017-11-05 01:13:31                1
# 1412392        1  2017-11-05 01:54:34   2017-11-05 01:19:59                3
# 1412420        1  2017-11-05 01:32:44   2017-11-05 01:03:49                4
# 1412459        1  2017-11-05 01:57:16   2017-11-05 01:01:46                2
# 1412485        1  2017-11-05 01:54:20   2017-11-05 01:12:46                1
# 1412503        1  2017-11-05 01:52:36   2017-11-05 01:09:44                1
# 1412505        1  2017-11-05 01:31:31   2017-11-05 01:07:21                1
# 1412515        1  2017-11-05 01:47:09   2017-11-05 01:02:33                3
# 1412520        1  2017-11-05 01:55:37   2017-11-05 01:05:29                1
# 1412536        1  2017-11-05 01:57:33   2017-11-05 01:19:55                1
# 1412557        1  2017-11-05 01:40:06   2017-11-05 01:00:41                1
# 1412584        1  2017-11-05 01:55:28   2017-11-05 01:01:57                3
# 1412591        1  2017-11-05 01:50:31   2017-11-05 01:29:19                2
# 1412594        1  2017-11-05 01:56:07   2017-11-05 01:04:22                3
# 1412619        1  2017-11-05 01:41:27   2017-11-05 01:14:37                1
# 1412623        1  2017-11-05 01:50:20   2017-11-05 01:25:07                1
# 1412625        1  2017-11-05 01:50:51   2017-11-05 01:16:22                2
# 1412645        1  2017-11-05 01:27:41   2017-11-05 01:14:12                1
# 1412684        1  2017-11-05 01:51:22   2017-11-05 01:05:01                2
# 1412692        1  2017-11-05 01:58:08   2017-11-05 01:08:39                1
# 1412698        1  2017-11-05 01:52:20   2017-11-05 01:01:57                4
# 1412722        1  2017-11-05 01:50:31   2017-11-05 01:23:23                2
# 1412740        1  2017-11-05 01:44:10   2017-11-05 01:06:07                1
# 1412749        1  2017-11-05 01:46:29   2017-11-05 01:02:02                1
# 1412785        1  2017-11-05 01:55:13   2017-11-05 01:02:30                1
# 1412808        1  2017-11-05 01:57:35   2017-11-05 01:01:58                2
# 1412871        1  2017-11-05 01:41:45   2017-11-05 01:03:47                4
#
#          trip_distance RatecodeID store_and_fwd_flag PULocationID  \
# 1383804            5.7          1                  N           79
# 1383813            2.4          1                  N          249
# 1383844            0.3          1                  N          236
# 1383858            1.7          1                  N           24
# 1383865            1.4          1                  N          158
# 1383899            5.2          1                  N          148
# 1383904            0.3          1                  N          264
# 1383925            3.4          1                  N          234
# 1383932            5.5          1                  N           79
# 1383936            2.1          1                  N          234
# 1383954            3.3          1                  N          144
# 1383958            2.7          1                  N           65
# 1383973            1.1          1                  N          107
# 1383975            4.6          1                  N          148
# 1383989            2.6          1                  N           90
# 1383995            2.6          1                  N          148
# 1384007            5.5          1                  N          234
# 1384011            2.8          1                  N           68
# 1384020            4.7          1                  N          249
# 1384023            6.5          1                  Y          186
# 1384032           15.7          1                  N          140
# 1384043            2.7          1                  N          144
# 1384054            3.0          1                  N          229
# 1384057            3.9          1                  N           79
# 1384060            4.5          1                  N          137
# 1384070            2.0          1                  N           68
# 1384092            4.5          1                  N          249
# 1384098            6.1          1                  N           48
# 1384103            7.8          1                  N          164
# 1384113            1.3          1                  N          249
# ...                ...        ...                ...          ...
# 1412354            3.3          1                  N          231
# 1412357            4.1          1                  N          262
# 1412367            5.5          1                  N           79
# 1412370           16.6          1                  N          114
# 1412392            8.3          1                  N           79
# 1412420            8.1          1                  N          211
# 1412459            0.6          1                  N          144
# 1412485            9.9          1                  N           45
# 1412503            1.3          1                  N          249
# 1412505           14.6          1                  N          161
# 1412515            2.6          1                  N          231
# 1412520            2.2          1                  N           79
# 1412536            4.9          1                  N           24
# 1412557            3.5          1                  N           79
# 1412584            1.4          1                  N            4
# 1412591            8.9          1                  N          114
# 1412594            0.9          1                  N          100
# 1412619            6.6          1                  N            7
# 1412623           10.1          1                  N          164
# 1412625            1.5          1                  N          114
# 1412645           19.6          1                  N          186
# 1412684            2.3          1                  N          114
# 1412692            2.7          1                  N           68
# 1412698            1.6          1                  N          249
# 1412722            7.1          1                  N          162
# 1412740            1.8          1                  N          107
# 1412749            1.2          1                  N           79
# 1412785            1.1          1                  N           68
# 1412808            0.8          1                  N           97
# 1412871            3.5          1                  N          231
#
#         DOLocationID payment_type          ...           tip_amount  \
# 1383804           61            1          ...                 4.75
# 1383813          162            1          ...                 1.00
# 1383844          236            2          ...                 0.00
# 1383858          116            1          ...                 1.85
# 1383865           79            1          ...                 1.00
# 1383899          145            1          ...                 4.35
# 1383904          264            1          ...                 1.05
# 1383925          143            1          ...                 2.75
# 1383932           61            1          ...                60.00
# 1383936           48            1          ...                 2.00
# 1383954           68            2          ...                 0.00
# 1383958          181            1          ...                 3.70
# 1383973          114            1          ...                 1.00
# 1383975           49            1          ...                 4.36
# 1383989          229            1          ...                 1.00
# 1383995           90            1          ...                 0.00
# 1384007           36            1          ...                 4.75
# 1384011          143            1          ...                 2.80
# 1384020          255            1          ...                 6.20
# 1384023          260            2          ...                 0.00
# 1384032           14            2          ...                 0.00
# 1384043          181            1          ...                 2.35
# 1384054          112            1          ...                 3.25
# 1384057           50            1          ...                 3.35
# 1384060          226            2          ...                 0.00
# 1384070          137            1          ...                 2.05
# 1384092          236            1          ...                 3.47
# 1384098           42            1          ...                 4.35
# 1384103          102            2          ...                 0.00
# 1384113          148            1          ...                 0.00
# ...              ...          ...          ...                  ...
# 1412354           48            2          ...                 0.00
# 1412357          186            1          ...                 3.55
# 1412367          239            1          ...                 4.25
# 1412370          265            1          ...                 8.00
# 1412392           41            1          ...                 5.65
# 1412420           74            1          ...                 2.00
# 1412459          148            1          ...                 1.25
# 1412485           14            1          ...                 5.85
# 1412503          148            2          ...                 0.00
# 1412505          174            1          ...                 2.00
# 1412515           90            1          ...                 2.00
# 1412520          170            1          ...                 2.05
# 1412536          235            2          ...                 0.00
# 1412557           80            2          ...                 0.00
# 1412584          224            1          ...                 1.00
# 1412591          141            1          ...                 6.55
# 1412594          230            1          ...                 1.65
# 1412619          151            1          ...                 5.36
# 1412623          228            1          ...                 6.85
# 1412625           79            3          ...                 0.00
# 1412645          134            1          ...                10.00
# 1412684          162            1          ...                 2.45
# 1412692           13            1          ...                 2.35
# 1412698          231            1          ...                 1.95
# 1412722           33            1          ...                 5.55
# 1412740          148            1          ...                 1.00
# 1412749          232            1          ...                 3.50
# 1412785          246            1          ...                 1.65
# 1412808           66            2          ...                 0.00
# 1412871          170            1          ...                 1.50
#
#          tolls_amount  improvement_surcharge  total_amount  travel_time  \
# 1383804          0.00                    0.3         28.55      -1921.0
# 1383813          0.00                    0.3         13.80      -2745.0
# 1383844          0.00                    0.3          5.30      -3417.0
# 1383858          0.00                    0.3         11.15      -3118.0
# 1383865          0.00                    0.3         11.30      -2915.0
# 1383899          0.00                    0.3         26.15      -1962.0
# 1383904          0.00                    0.3          6.35      -3383.0
# 1383925          0.00                    0.3         16.55      -2835.0
# 1383932          0.00                    0.3         85.30      -1621.0
# 1383936          0.00                    0.3         13.30      -2877.0
# 1383954          0.00                    0.3         15.30      -2528.0
# 1383958          0.00                    0.3         18.50      -2576.0
# 1383973          0.00                    0.3          8.80      -3157.0
# 1383975          0.00                    0.3         26.16      -1973.0
# 1383989          0.00                    0.3         13.30      -2889.0
# 1383995          0.00                    0.3         15.30      -2363.0
# 1384007          0.00                    0.3         28.55      -1824.0
# 1384011          0.00                    0.3         14.10      -3073.0
# 1384020          0.00                    0.3         31.00      -1568.0
# 1384023          0.00                    0.3         24.80      -1877.0
# 1384032          0.00                    0.3         48.30      -1108.0
# 1384043          0.00                    0.3         14.15      -3077.0
# 1384054          0.00                    0.3         19.55      -2260.0
# 1384057          0.00                    0.3         20.15      -2406.0
# 1384060          0.00                    0.3         19.80      -2116.0
# 1384070          0.00                    0.3         12.35      -2990.0
# 1384092          0.00                    0.3         22.77      -2291.0
# 1384098          0.00                    0.3         26.15      -2332.0
# 1384103          5.76                    0.3         36.06      -1382.0
# 1384113          0.00                    0.3         10.80      -2818.0
# ...               ...                    ...           ...          ...
# 1412354          0.00                    0.3         16.80      -2314.0
# 1412357          0.00                    0.3         21.35      -2408.0
# 1412367          0.00                    0.3         25.55      -2145.0
# 1412370          2.64                    0.3         59.44      -1230.0
# 1412392          0.00                    0.3         33.95      -2075.0
# 1412420          0.00                    0.3         25.80      -1735.0
# 1412459          0.00                    0.3          7.55      -3330.0
# 1412485          0.00                    0.3         35.15      -2494.0
# 1412503          0.00                    0.3         13.30      -2572.0
# 1412505          2.64                    0.3         49.44      -1450.0
# 1412515          0.00                    0.3         15.30      -2676.0
# 1412520          0.00                    0.3         12.35      -3008.0
# 1412536          0.00                    0.3         19.80      -2258.0
# 1412557          0.00                    0.3         17.80      -2365.0
# 1412584          0.00                    0.3          9.30      -3211.0
# 1412591          0.00                    0.3         39.35      -1272.0
# 1412594          0.00                    0.3          9.95      -3105.0
# 1412619          0.00                    0.3         32.16      -1610.0
# 1412623          0.00                    0.3         41.15      -1513.0
# 1412625          0.00                    0.3         17.30      -2069.0
# 1412645          5.76                    0.3         74.06       -809.0
# 1412684          0.00                    0.3         14.75      -2781.0
# 1412692          0.00                    0.3         14.15      -2969.0
# 1412698          0.00                    0.3         11.75      -3023.0
# 1412722          0.00                    0.3         33.35      -1628.0
# 1412740          0.00                    0.3         16.80      -2283.0
# 1412749          0.00                    0.3         15.30      -2667.0
# 1412785          0.00                    0.3          9.95      -3163.0
# 1412808          0.00                    0.3          6.30      -3337.0
# 1412871          0.00                    0.3         18.30      -2278.0
#
#          average_speed  tpep_pickup_hour  tpep_dropoff_hour  \
# 1383804     -10.681936                 1                  1
# 1383813      -3.147541                 1                  1
# 1383844      -0.316067                 1                  1
# 1383858      -1.962797                 1                  1
# 1383865      -1.728988                 1                  1
# 1383899      -9.541284                 1                  1
# 1383904      -0.319243                 1                  1
# 1383925      -4.317460                 1                  1
# 1383932     -12.214682                 1                  1
# 1383936      -2.627737                 1                  1
# 1383954      -4.699367                 1                  1
# 1383958      -3.773292                 1                  1
# 1383973      -1.254355                 1                  1
# 1383975      -8.393310                 1                  1
# 1383989      -3.239875                 1                  1
# 1383995      -3.961066                 1                  1
# 1384007     -10.855263                 1                  1
# 1384011      -3.280182                 1                  1
# 1384020     -10.790816                 1                  1
# 1384023     -12.466702                 1                  1
# 1384032     -51.010830                 1                  1
# 1384043      -3.158921                 1                  1
# 1384054      -4.778761                 1                  1
# 1384057      -5.835411                 1                  1
# 1384060      -7.655955                 1                  1
# 1384070      -2.408027                 1                  1
# 1384092      -7.071148                 1                  1
# 1384098      -9.416810                 1                  1
# 1384103     -20.318379                 1                  1
# 1384113      -1.660752                 1                  1
# ...                ...               ...                ...
# 1412354      -5.133967                 1                  1
# 1412357      -6.129568                 1                  1
# 1412367      -9.230769                 1                  1
# 1412370     -48.585366                 1                  1
# 1412392     -14.400000                 1                  1
# 1412420     -16.806916                 1                  1
# 1412459      -0.648649                 1                  1
# 1412485     -14.290297                 1                  1
# 1412503      -1.819596                 1                  1
# 1412505     -36.248276                 1                  1
# 1412515      -3.497758                 1                  1
# 1412520      -2.632979                 1                  1
# 1412536      -7.812223                 1                  1
# 1412557      -5.327696                 1                  1
# 1412584      -1.569604                 1                  1
# 1412591     -25.188679                 1                  1
# 1412594      -1.043478                 1                  1
# 1412619     -14.757764                 1                  1
# 1412623     -24.031725                 1                  1
# 1412625      -2.609957                 1                  1
# 1412645     -87.218789                 1                  1
# 1412684      -2.977346                 1                  1
# 1412692      -3.273830                 1                  1
# 1412698      -1.905392                 1                  1
# 1412722     -15.700246                 1                  1
# 1412740      -2.838371                 1                  1
# 1412749      -1.619798                 1                  1
# 1412785      -1.251976                 1                  1
# 1412808      -0.863051                 1                  1
# 1412871      -5.531168                 1                  1
#
#          tpep_pickup_weekday  tpep_dropoff_weekday
# 1383804                    6                     6
# 1383813                    6                     6
# 1383844                    6                     6
# 1383858                    6                     6
# 1383865                    6                     6
# 1383899                    6                     6
# 1383904                    6                     6
# 1383925                    6                     6
# 1383932                    6                     6
# 1383936                    6                     6
# 1383954                    6                     6
# 1383958                    6                     6
# 1383973                    6                     6
# 1383975                    6                     6
# 1383989                    6                     6
# 1383995                    6                     6
# 1384007                    6                     6
# 1384011                    6                     6
# 1384020                    6                     6
# 1384023                    6                     6
# 1384032                    6                     6
# 1384043                    6                     6
# 1384054                    6                     6
# 1384057                    6                     6
# 1384060                    6                     6
# 1384070                    6                     6
# 1384092                    6                     6
# 1384098                    6                     6
# 1384103                    6                     6
# 1384113                    6                     6
# ...                      ...                   ...
# 1412354                    6                     6
# 1412357                    6                     6
# 1412367                    6                     6
# 1412370                    6                     6
# 1412392                    6                     6
# 1412420                    6                     6
# 1412459                    6                     6
# 1412485                    6                     6
# 1412503                    6                     6
# 1412505                    6                     6
# 1412515                    6                     6
# 1412520                    6                     6
# 1412536                    6                     6
# 1412557                    6                     6
# 1412584                    6                     6
# 1412591                    6                     6
# 1412594                    6                     6
# 1412619                    6                     6
# 1412623                    6                     6
# 1412625                    6                     6
# 1412645                    6                     6
# 1412684                    6                     6
# 1412692                    6                     6
# 1412698                    6                     6
# 1412722                    6                     6
# 1412740                    6                     6
# 1412749                    6                     6
# 1412785                    6                     6
# 1412808                    6                     6
# 1412871                    6                     6
#
# [1413 rows x 23 columns]

# %%
df_mes = df_mes[df_mes['travel_time'] > 0]
df_mes.shape[0]
# Out:
# 9174132

# %% [markdown]
# All in all we have gone from 10294628 to 10171487 rows. We are still keeping **98.8% of the initial dataset**

# %% [markdown]
# ### Filling out code variables
# In order to encode all code variables (i.e. those that take string values, not numeric), and not miss any column if in the dataset a variable doesn't have a certain code, I am adding at the end of the dataframe new rows with all the vaules for these code varibles. I will remove these rows from the dataframe once they are encoded.

# %%
print(sorted(df_mes['payment_type'].unique()))
# Out:
# ['1', '2', '3', '4']

# %%
print(sorted(df_mes['RatecodeID'].unique()))
# Out:
# ['1', '2', '3', '4', '5', '6', '99']

# %%
df_mes['PULocationID'].unique().shape
# Out:
# (258,)

# %%
df_mes[df_mes['PULocationID'].astype('int64') >= 266]
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, travel_time, average_speed, tpep_pickup_hour, tpep_dropoff_hour, tpep_pickup_weekday, tpep_dropoff_weekday]
# Index: []
#
# [0 rows x 23 columns]

# %%
df_mes['DOLocationID'].unique().shape
# Out:
# (262,)

# %%
df_mes[df_mes['DOLocationID'].astype('int64') >= 266]
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, travel_time, average_speed, tpep_pickup_hour, tpep_dropoff_hour, tpep_pickup_weekday, tpep_dropoff_weekday]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# All in all, we see that "payment_type" is mising 2 values (5 & 6), the locations also miss some out of the 265 listed in the document, and "RatecodeID" has an extra one: 99. As it is unknown for us, we wil get rid of the values (we can see there are only few of them)

# %%
df_mes[df_mes['RatecodeID'] == '99']
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 2561193        1  2017-11-08 21:21:51   2017-11-08 21:25:58                1
#
#          trip_distance RatecodeID store_and_fwd_flag PULocationID  \
# 2561193            0.9         99                  N           48
#
#         DOLocationID payment_type          ...           tip_amount  \
# 2561193           48            1          ...                 1.85
#
#          tolls_amount  improvement_surcharge  total_amount  travel_time  \
# 2561193           0.0                    0.3          8.15        247.0
#
#          average_speed  tpep_pickup_hour  tpep_dropoff_hour  \
# 2561193      13.117409                21                 21
#
#          tpep_pickup_weekday  tpep_dropoff_weekday
# 2561193                    2                     2
#
# [1 rows x 23 columns]

# %%
df_mes = df_mes[df_mes['RatecodeID'] != '99']

# %% [markdown]
# ## Model Building

# %% [markdown]
# I am importing model created for March

# %%
# Due to memory issues, I'll work with a smaller dataset.
df_mes2 = df_mes.sample(n=1000000, random_state=0) #.iloc[0:1000000,:]

# %%
shape1 = df_mes2.shape[0]
df2 = pd.DataFrame([['1'], ['2']], columns=(['VendorID']))
df3 = [str(x) for x in range(1,266)]
df3 = pd.DataFrame({'PULocationID':df3, 'DOLocationID':df3})
df4 = pd.DataFrame([['Y'], ['N']], columns=(['store_and_fwd_flag']))
df5 = [str(x) for x in range(1,7)]
df5 = pd.DataFrame({'payment_type':df5, 'RatecodeID':df5})

df_mes2 = df_mes2.append(df2, sort=False, ignore_index=True)
df_mes2 = df_mes2.append(df3, sort=False, ignore_index=True)
df_mes2 = df_mes2.append(df4, sort=False, ignore_index=True)
df_mes2 = df_mes2.append(df5, sort=False, ignore_index=True)

df_mes2.fillna(1, inplace=True) #1 is a value every string column has, so I am not adding new values here

# %%
df_mes2 = df_mes2.drop(['tpep_pickup_datetime','tpep_dropoff_datetime'], axis=1)
df_mes2 = pd.get_dummies(df_mes2, drop_first=True)

# %%
df_mes2 = df_mes2.head(shape1)

# %%
cols = list(df_mes2.columns)
cols.remove('tip_amount')

# %%
#Divide the dataset into input variables and output 
# (I get a memory error if I work with the whole set, so I'm reducing it to 1.000.000 rows)
X = df_mes2.loc[0:1000000,cols]
Y = df_mes2.loc[0:1000000,['tip_amount']]

# %% [markdown]
# ### Model: Linear Regression
# We start with a simple model in order to get a baseline to compare the rest

# %%
# %store -r lin_reg

# %%
Y_lin_reg = lin_reg.predict(X)

from sklearn import metrics
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y, Y_lin_reg)))
print('Variance explained: ', metrics.explained_variance_score(Y, Y_lin_reg))
# Out:
# RMSE: 0.07536055230800988
# Variance explained:  0.9990635594084737

# %% [markdown]
# This model explains 99.8% of the variance, and predicts the tip with a precission of around 9.7 cents (RMSE)

# %% [markdown]
# Another test:

# %%
start_time = time.time()

# %%
df_mes2 = df_mes.iloc[5000000:6000000,:]

shape1 = df_mes2.shape[0]
df2 = pd.DataFrame([['1'], ['2']], columns=(['VendorID']))
df3 = [str(x) for x in range(1,266)]
df3 = pd.DataFrame({'PULocationID':df3, 'DOLocationID':df3})
df4 = pd.DataFrame([['Y'], ['N']], columns=(['store_and_fwd_flag']))
df5 = [str(x) for x in range(1,7)]
df5 = pd.DataFrame({'payment_type':df5, 'RatecodeID':df5})

df_mes2 = df_mes2.append(df2, sort=False, ignore_index=True)
df_mes2 = df_mes2.append(df3, sort=False, ignore_index=True)
df_mes2 = df_mes2.append(df4, sort=False, ignore_index=True)
df_mes2 = df_mes2.append(df5, sort=False, ignore_index=True)

df_mes2.fillna(1, inplace=True) #1 is a value every string column has, so I am not adding new values here

df_mes2 = df_mes2.drop(['tpep_pickup_datetime','tpep_dropoff_datetime'], axis=1)
df_mes2 = pd.get_dummies(df_mes2, drop_first=True)

df_mes2 = df_mes2.head(shape1)

cols = list(df_mes2.columns)
cols.remove('tip_amount')

#Divide the dataset into input variables and output 
# (I get a memory error if I work with the whole set, so I'm reducing it to 1.000.000 rows)
X2 = df_mes2.loc[:,cols]
Y2 = df_mes2.loc[:,['tip_amount']]

# %%
Y_lin_reg = lin_reg.predict(X2)

from sklearn import metrics
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y2, Y_lin_reg)))
print('Variance explained: ', metrics.explained_variance_score(Y2, Y_lin_reg))
# Out:
# RMSE: 0.06792136760249438
# Variance explained:  0.9992105019510663

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 22.715147495269775 seconds ---
